# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def func(x):
    return 2 * x**2 - 7

# %%
x_values = np.linspace(-3, 3, 400)
y_values = func(x_values)

# %%
def plox():

    for highlight_x in np.linspace(-3, 3, 100):
        y = func(highlight_x)
        plt.plot(x_values, y_values, label=r'$y = 2x^x - 7$', color='blue')
        plt.scatter([highlight_x], [highlight_y], color='red', zorder=5, label=f'Highlight: ({highlight_x}, {highlight_y:.2f})')
        plt.title(r'Plot of $y = 2x^x - 7$ with Highlighted Point')
        plt.xlabel('x')
        plt.ylabel('y')
        plt.legend()
        plt.show()
